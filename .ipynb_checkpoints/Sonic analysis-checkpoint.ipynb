# %% [markdown]
# # Analysis of the sonic effects of music
# ##### Author: Otuokere Tobechukwu. O
# ##### Github: github.com/OtuokereTobechukwu

# %% [markdown]
# ### Introduction
#
# Music has been a wonder since time began.
# Don't try imagining Life without it.
#
# Frequently, very interesting questions pop up in my mind as regards how we humans percieve the sonic contents of music, how it affects us and how audio contents have evolved.
#
# This is an attempt, through Exploratory Data Analysis, to answer these questions.

# %% [markdown]
# ## How is this analysis organized?

# %% [markdown]
# ### Contents:
# <ul><b>1. Data description</b></ul>
# <ul><b>2. Importing essential libraries and dataset</b></ul>
# <ul><b>3. Descriptive statistics</b></ul>
# <ul><b>4. Data processing</b></ul>
# <ul><b>5. Distrubution and correlation plots</b></ul>
# <ul><b>6. Observations</b></ul>
# <ul><b>7. How have things changed over time?</b></ul>

# %% [markdown]
# ### Data description
#
# Reference - https://developer.spotify.com/documentation/web-api/reference/tracks/get-audio-features/
#
#     duration_ms - The duration of the track in milliseconds.
#
#     key - The estimated overall key of the track. Integers map to pitches using standard Pitch Class notation . E.g. 0 = C, 1 = C♯/D♭, 2 = D, and so on. If no key was detected, the value is -1.
#
#     mode - Mode indicates the modality (major or minor) of a track, the type of scale from which its melodic content is derived. Major is represented by 1 and minor is 0.
#
#     time_signature - An estimated overall time signature of a track. The time signature (meter) is a notational convention to specify how many beats are in each bar (or measure).
#     acousticness - A confidence measure from 0.0 to 1.0 of whether the track is acoustic. 1.0 represents high confidence the track is acoustic. The distribution of values for this feature look like this: Acousticness
#
#     danceability - Danceability describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. A value of 0.0 is least danceable and 1.0 is most danceable. The distribution of values for this feature look like this: Danceability distribution
#
#     energy - Energy is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy. For example, death metal has high energy, while a Bach prelude scores low on the scale. Perceptual features contributing to this attribute include dynamic range, perceived loudness, timbre, onset rate, and general entropy. The distribution of values for this feature look like this: Energy distribution
#
#     instrumentalness - Predicts whether a track contains no vocals. “Ooh” and “aah” sounds are treated as instrumental in this context. Rap or spoken word tracks are clearly “vocal”. The closer the instrumentalness value is to 1.0, the greater likelihood the track contains no vocal content. Values above 0.5 are intended to represent instrumental tracks, but confidence is higher as the value approaches 1.0. The distribution of values for this feature look like this: Instrumentalness distribution
#
#     liveness - Detects the presence of an audience in the recording. Higher liveness values represent an increased probability that the track was performed live. A value above 0.8 provides strong likelihood that the track is live. The distribution of values for this feature look like this: Liveness distribution
#
#     loudness - The overall loudness of a track in decibels (dB). Loudness values are averaged across the entire track and are useful for comparing relative loudness of tracks. Loudness is the quality of a sound that is the primary psychological correlate of physical strength (amplitude). Values typical range between -60 and 0 db. The distribution of values for this feature look like this: Loudness distribution
#
#     speechiness - Speechiness detects the presence of spoken words in a track. The more exclusively speech-like the recording (e.g. talk show, audio book, poetry), the closer to 1.0 the attribute value. Values above 0.66 describe tracks that are probably made entirely of spoken words. Values between 0.33 and 0.66 describe tracks that may contain both music and speech, either in sections or layered, including such cases as rap music. Values below 0.33 most likely represent music and other non-speech-like tracks. The distribution of values for this feature look like this: Speechiness distribution
#
#     valence - A measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric), while tracks with low valence sound more negative (e.g. sad, depressed, angry). The distribution of values for this feature look like this: Valence distribution
#
#     tempo - The overall estimated tempo of a track in beats per minute (BPM). In musical terminology, tempo is the speed or pace of a given piece and derives directly from the average beat duration. The distribution of values for this feature look like this: Tempo
#
#     id - The Spotify ID for the track
#
#     type - The object type: “audio_features”
#
#     popularity - The popularity of the track. The value will be between 0 and 100, with 100 being the most popular. The popularity is calculated by algorithm and is based, in the most part, on the total number of plays the track has had and how recent those plays are. Generally speaking, songs that are being played a lot now will have a higher popularity than songs that were played a lot in the past. Artist and album popularity is derived mathematically from track popularity. Note that the popularity value may lag actual popularity by a few days: the value is not updated in real time

# %% [markdown]
# ## Importing essential libraries and dataset

# %%
# Importing needed libraries
import time
import warnings
import pandas  as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Importing the dataset

# %%
dataset = pd.read_csv('data.csv')
ds_genre = pd.read_csv('data_by_genres.csv')
ds_artist = pd.read_csv('data_by_artist.csv')
ds_year = pd.read_csv('data_by_year.csv')
ds_genre2 = pd.read_csv('data_w_genres.csv')


# Overview of the dataset.
dataset.head()

# %% [markdown]
# ### Descriptive Statistics

# %%
dataset.info()

# %%
# Descriptive statistics of the dataset
dataset.describe()

# %% [markdown]
# ### A little data processing ...
#
# The first column in the dataframe is not essential for this analysis.
#
# Also, we won't be needing the categorical columns just yet so we are going to drop them.

# %%
# Dropping the First column

dataset = dataset.drop(columns = dataset.columns[0])

# %%
# Dropping all categorical variables

cat_cols = ['artists', 'name', 'id']
numeric_cols = dataset.drop(columns=cat_cols)
numeric_cols.head()

# %% [markdown]
# In terms of the duration of songs, the millisecond is the unit of measurement in this dataset
#
# We'll need to convert that to minutes to get a more representative idea

# %%
numeric_cols['duration_mins'] = (numeric_cols['duration_ms']/(1000*60))%60
numeric_cols = numeric_cols.drop(columns = ['duration_ms'])
numeric_cols.head()

# %% [markdown]
# Now that has been dropped. Let's get visual!
#
# Let's begin by showcasing the distrubution of the sonic features in this dataset

# %% [markdown]
# ### Distrubution of the sonic features

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
numeric_cols.hist(bins=50, figsize=(15,10))
plt.show()

# %% [markdown]
# The above visual showcases the distrubution of the sonic features in this dataset.
#
# Let's briefly highlight some of the striking patterns we can observe here:
#
# #### Danceability
# This feature is normally distrubuted with the values centered around the mean(0.53). A little outlier exists on the left of the distrubution curve which indicates that a few songs were not danceable at all. I wonder what that sounds like.
#
# #### Duration(minutes)
# A lot of songs appear to be within 2-6 minutes mark with a few exceptions lasting up to about 12-15 mins. Pretty long isn't it?
#
# #### Energy
# Energy seems to be fairly uniformly distrubuted
#
# #### Loudness
#
# #### Tempo
# Measured in Beats Per Minute(bpm), this feature apppears to be fairly normally distrubuted with most songs falling between 70bpm - 150bpm

# %% [markdown]
# #### Next, we take a look at the correlation between features in this dataset.

# %%
# A seaborn Correlation matrix

sns.set(style = "white", font_scale = 1)

corr = numeric_cols.corr()

mask = np.zeros_like(corr, dtype = np.bool)
mask[np.triu_indices_from(mask)] = True

f, ax = plt.subplots(figsize = (20, 15))
f.suptitle('Correlation Matrix of sonic Characteristics', fontsize = 20)


cmap = sns.diverging_palette(520, 10, as_cmap= True)

sns.heatmap(corr, mask=mask, cmap=cmap, vmax= 3, center = 0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

plt.show()

# %% [markdown]
# ### Observations from the correlation visual
#
# Let's talk about them in two categories: Negative and Positive correlations
#
# #### Negative correlations
# <ul>Our first observation here highlights the strong negative correlation between the "year" and "acousticness" features.
# This simply means that as years pass, the acousticness of songs/music reduce drastically.</ul>
#
# <ul>Likewise, in the same manner, the "acousticness" and "energy" features have a strong negative correlation for obvious reasons.
# The more energetic a song is, the less likely it is to be acoustic.</ul>
#
# <ul>A couple of other features like acousticness and loudness, acousticness and popularity share same sentiments.</ul>
#
# #### Positive correlations
# <ul>The strongest positive correlation we have in the figure above is between "popularity" and "year" features.
# The advent of the internet should be one of the major contributing factors to this interesting observation. Music has been able to spread faster and reach an unending variety of listeners hence contributing to the popularity of both the song and the artist.</ul>
#
# <ul>Another noteworthy observation to point out is the strong correlation between <b>"energy" and "loudness".</b></ul>
#
# <ul>Also, there is an interesting correlation between year and explicit content. This is not surprising given the amount of sexual content on display in recent years. In terms of loudness, the correlation plot also establishes the relationship between advancing years and the loudness of the music being produced
#
#
#
# For a more granular view of the correlation between features,

# %%
plt.figure(figsize=(16, 8))
sns.set(style = "white", font_scale = 1)

corr = numeric_cols.corr()



sns.heatmap(corr, annot=True, cmap="coolwarm")
#plt.show()

# %% [markdown]
# ### Now let's shift our focus to more specific sonic properties
#
# First, we gather the necessary features:

# %%
popularity = numeric_cols['popularity']
sonic_features = numeric_cols.drop(columns=['danceability', 'key',
                                              'mode', 'popularity', 'year',
                                              'valence','explicit', 'release_date', 'speechiness'])
sonic_features.head()

# %%
#Correlation visual
sonic_features.corrwith(popularity).plot.bar(figsize= (15,5),
                                          title = "Correlation with Popularity",
                                          fontsize= 12, rot = 45,
                                         grid = True) 
plt.show()

# %% [markdown]
# ## How have things changed overtime?

# %% [markdown]
# To answer this question, we need to make some plots and see how some of these features have changed overtime.
#
# This dataset as we know contains records from as far back as 1921. A bird's eye view of these features will show exactly how things have changed.

# %% [markdown]
# First we find the average of these features per year:

# %%
# A function to compute the averages

def year_average(cols, df):
    return df[cols].groupby('year').mean().sort_values(by='year').reset_index()

columns = ['acousticness', 'energy', 'instrumentalness', 'loudness', 'duration_mins', 'danceability', 'explicit', 'year']

year_avg_df = year_average(columns, numeric_cols)
year_avg_df.head()

# %% [markdown]
# A line chart for the previous dataframe......

# %%
plt.figure(figsize=(16,10))

plt.title("Sonic characteristics Over Time", fontsize=15)
chart_lines = ['acousticness', 'energy', 'instrumentalness', 'explicit','danceability']

for line in chart_lines:
    ax = sns.lineplot(x='year', y=line, data=year_avg_df)

plt.legend(chart_lines)

# %% [markdown]
# ## To dig deeper, let's take a look at some of the most influential artists of the 20th Century
#
# First, we look at the data....

# %%
ds_artist.head()
# Out:
#                    artists  acousticness  danceability  duration_ms    energy  \
# 0         Francisco Canaro      0.983072      0.654711  177776.5135  0.292622
# 1          Frédéric Chopin      0.989961      0.340087  251871.9485  0.106874
# 2     Ludwig van Beethoven      0.955019      0.340157  439361.3316  0.153176
# 3  Wolfgang Amadeus Mozart      0.962084      0.353895  327808.0373  0.138348
# 4    Johann Sebastian Bach      0.958405      0.354224  203461.7579  0.201932
#
#    instrumentalness  liveness   loudness  speechiness       tempo   valence  \
# 0          0.490675  0.201118 -11.733373     0.111007  123.608786  0.746469
# 1          0.876899  0.155677 -22.575578     0.042913   90.977772  0.203644
# 2          0.690770  0.164078 -20.107704     0.055550  104.833536  0.260255
# 3          0.514837  0.187091 -20.214154     0.067756  108.594920  0.332855
# 4          0.744322  0.165837 -20.936518     0.048844  106.551869  0.570526
#
#    popularity  key  mode  count
# 0    0.054257    2     1   2267
# 1    5.748127    1     1   1068
# 2    5.237306    0     1    965
# 3    9.624870    7     1    965
# 4   14.704669    7     1    921

# %%
artist_cols = ['artists', 'acousticness','danceability',
               'duration_ms', 'energy', 'instrumentalness',
               'liveness','loudness', 'speechiness', 'valence', 'popularity']
artist_pivot = ds_artist[artist_cols].groupby('artists')
artist_pivot.apply(lambda _df: _df.sort_values(by=['popularity'], ascending=False))
# Out:
#                                                                                                     artists  \
# artists
# "Cats" 1981 Original London Cast                   4086                    "Cats" 1981 Original London Cast
# "Cats" 1983 Broadway Cast                          2081                           "Cats" 1983 Broadway Cast
# "Fiddler On The Roof” Motion Picture Chorus        5668         "Fiddler On The Roof” Motion Picture Chorus
# "Fiddler On The Roof” Motion Picture Orchestra     3039      "Fiddler On The Roof” Motion Picture Orchestra
# "Joseph And The Amazing Technicolor Dreamcoat" ... 4128   "Joseph And The Amazing Technicolor Dreamcoat"...
# "Joseph And The Amazing Technicolor Dreamcoat" ... 2005   "Joseph And The Amazing Technicolor Dreamcoat"...
# "Mama" Helen Teagarden                             25428                             "Mama" Helen Teagarden
# "Mista Dj Paul                                     19982                                     "Mista Dj Paul
# "Test for Victor Young"                            17886                            "Test for Victor Young"
# "Weird Al" Yankovic                                508                                  "Weird Al" Yankovic
# $IMEON                                             16083                                             $IMEON
# $NOT                                               7359                                                $NOT
# $pyda                                              19531                                              $pyda
# $uicideBoy$                                        565                                          $uicideBoy$
# 'Be More Chill' Ensemble                           23275                           'Be More Chill' Ensemble
# 'In The Heights' Original Broadway Company         4453          'In The Heights' Original Broadway Company
# 'Legally Blonde' Ensemble                          4452                           'Legally Blonde' Ensemble
# 'Legally Blonde' Greek Chorus                      12827                      'Legally Blonde' Greek Chorus
# 'Little Women' Original Broadway Cast              20927              'Little Women' Original Broadway Cast
# 'The Book of Mormon' Original Broadway Cast Com... 22893  'The Book of Mormon' Original Broadway Cast Co...
# 'Til Tuesday                                       4956                                        'Til Tuesday
# ((( O )))                                          19283                                          ((( O )))
# (Con La Participación De Eros Ramazzotti)          21640          (Con La Participación De Eros Ramazzotti)
# (G)I-DLE                                           13704                                           (G)I-DLE
# (Hed) P.E.                                         6367                                          (Hed) P.E.
# (Sandy) Alex G                                     16865                                     (Sandy) Alex G
# *NSYNC                                             915                                               *NSYNC
# -                                                  15435                                                  -
# ...And You Will Know Us by the Trail of Dead       26104       ...And You Will Know Us by the Trail of Dead
# ...Bender                                          26720                                          ...Bender
# ...                                                                                                     ...
# 王秀如                                                3515                                                 王秀如
# 環球管弦樂隊                                             4538                                              環球管弦樂隊
# 白光                                                 1835                                                  白光
# 福居良                                                5972                                                 福居良
# 秋元薫                                                9469                                                 秋元薫
# 童安格                                                10168                                                童安格
# 笠井 紀美子                                             15355                                             笠井 紀美子
# 紫薇                                                 700                                                   紫薇
# 羅大佑                                                7022                                                 羅大佑
# 葉歡                                                 23903                                                 葉歡
# 葛蘭                                                 2088                                                  葛蘭
# 蔡楓華                                                23806                                                蔡楓華
# 蔣志光                                                21659                                                蔣志光
# 虞戡平                                                18384                                                虞戡平
# 謝雷                                                 22682                                                 謝雷
# 賴佩霞                                                16732                                                賴佩霞
# 辛曉琪                                                15113                                                辛曉琪
# 那英                                                 21018                                                 那英
# 鄭怡                                                 21339                                                 鄭怡
# 金智娟                                                18236                                                金智娟
# 鈴木 弘                                               9347                                                鈴木 弘
# 陳秀男                                                11880                                                陳秀男
# 陳蘭麗                                                17682                                                陳蘭麗
# 霜華雪華                                               759                                                 霜華雪華
# 韋綺珊                                                20254                                                韋綺珊
# 高慧君                                                22672                                                高慧君
# 黃品源                                                21126                                                黃品源
# 黑豹                                                 24319                                                 黑豹
# 나현희                                                6962                                                 나현희
# 칼라 Color                                           7964                                            칼라 Color
#
#                                                           acousticness  \
# artists
# "Cats" 1981 Original London Cast                   4086       0.591000
# "Cats" 1983 Broadway Cast                          2081       0.857095
# "Fiddler On The Roof” Motion Picture Chorus        5668       0.856571
# "Fiddler On The Roof” Motion Picture Orchestra     3039       0.887500
# "Joseph And The Amazing Technicolor Dreamcoat" ... 4128       0.538000
# "Joseph And The Amazing Technicolor Dreamcoat" ... 2005       0.591477
# "Mama" Helen Teagarden                             25428      0.725000
# "Mista Dj Paul                                     19982      0.006900
# "Test for Victor Young"                            17886      0.927000
# "Weird Al" Yankovic                                508        0.181191
# $IMEON                                             16083      0.422000
# $NOT                                               7359       0.524000
# $pyda                                              19531      0.000122
# $uicideBoy$                                        565        0.123657
# 'Be More Chill' Ensemble                           23275      0.764000
# 'In The Heights' Original Broadway Company         4453       0.648333
# 'Legally Blonde' Ensemble                          4452       0.580222
# 'Legally Blonde' Greek Chorus                      12827      0.604500
# 'Little Women' Original Broadway Cast              20927      0.902000
# 'The Book of Mormon' Original Broadway Cast Com... 22893      0.297000
# 'Til Tuesday                                       4956       0.105556
# ((( O )))                                          19283      0.847000
# (Con La Participación De Eros Ramazzotti)          21640      0.282000
# (G)I-DLE                                           13704      0.027050
# (Hed) P.E.                                         6367       0.009742
# (Sandy) Alex G                                     16865      0.514000
# *NSYNC                                             915        0.148876
# -                                                  15435      0.466000
# ...And You Will Know Us by the Trail of Dead       26104      0.008410
# ...Bender                                          26720      0.000155
# ...                                                                ...
# 王秀如                                                3515       0.894750
# 環球管弦樂隊                                             4538       0.897222
# 白光                                                 1835       0.978792
# 福居良                                                5972       0.782500
# 秋元薫                                                9469       0.124133
# 童安格                                                10168      0.369667
# 笠井 紀美子                                             15355      0.085600
# 紫薇                                                 700        0.723964
# 羅大佑                                                7022       0.300400
# 葉歡                                                 23903      0.308000
# 葛蘭                                                 2088       0.840095
# 蔡楓華                                                23806      0.138000
# 蔣志光                                                21659      0.758000
# 虞戡平                                                18384      0.847000
# 謝雷                                                 22682      0.649000
# 賴佩霞                                                16732      0.978000
# 辛曉琪                                                15113      0.702500
# 那英                                                 21018      0.787000
# 鄭怡                                                 21339      0.536000
# 金智娟                                                18236      0.536000
# 鈴木 弘                                               9347       0.503333
# 陳秀男                                                11880      0.473500
# 陳蘭麗                                                17682      0.502000
# 霜華雪華                                               759        0.919692
# 韋綺珊                                                20254      0.758000
# 高慧君                                                22672      0.686000
# 黃品源                                                21126      0.541000
# 黑豹                                                 24319      0.381000
# 나현희                                                6962       0.428460
# 칼라 Color                                           7964       0.317025
#
#                                                           danceability  \
# artists
# "Cats" 1981 Original London Cast                   4086       0.449100
# "Cats" 1983 Broadway Cast                          2081       0.450000
# "Fiddler On The Roof” Motion Picture Chorus        5668       0.348286
# "Fiddler On The Roof” Motion Picture Orchestra     3039       0.416000
# "Joseph And The Amazing Technicolor Dreamcoat" ... 4128       0.496500
# "Joseph And The Amazing Technicolor Dreamcoat" ... 2005       0.488045
# "Mama" Helen Teagarden                             25428      0.637000
# "Mista Dj Paul                                     19982      0.849000
# "Test for Victor Young"                            17886      0.734000
# "Weird Al" Yankovic                                508        0.664243
# $IMEON                                             16083      0.798000
# $NOT                                               7359       0.742400
# $pyda                                              19531      0.514000
# $uicideBoy$                                        565        0.769615
# 'Be More Chill' Ensemble                           23275      0.497000
# 'In The Heights' Original Broadway Company         4453       0.533000
# 'Legally Blonde' Ensemble                          4452       0.628000
# 'Legally Blonde' Greek Chorus                      12827      0.773500
# 'Little Women' Original Broadway Cast              20927      0.345000
# 'The Book of Mormon' Original Broadway Cast Com... 22893      0.486000
# 'Til Tuesday                                       4956       0.557125
# ((( O )))                                          19283      0.410000
# (Con La Participación De Eros Ramazzotti)          21640      0.722000
# (G)I-DLE                                           13704      0.680000
# (Hed) P.E.                                         6367       0.593167
# (Sandy) Alex G                                     16865      0.650000
# *NSYNC                                             915        0.645091
# -                                                  15435      0.446000
# ...And You Will Know Us by the Trail of Dead       26104      0.255000
# ...Bender                                          26720      0.542000
# ...                                                                ...
# 王秀如                                                3515       0.373417
# 環球管弦樂隊                                             4538       0.639889
# 白光                                                 1835       0.396625
# 福居良                                                5972       0.463167
# 秋元薫                                                9469       0.742333
# 童安格                                                10168      0.477333
# 笠井 紀美子                                             15355      0.614000
# 紫薇                                                 700        0.468964
# 羅大佑                                                7022       0.630200
# 葉歡                                                 23903      0.618000
# 葛蘭                                                 2088       0.534667
# 蔡楓華                                                23806      0.611000
# 蔣志光                                                21659      0.588000
# 虞戡平                                                18384      0.290000
# 謝雷                                                 22682      0.537000
# 賴佩霞                                                16732      0.261000
# 辛曉琪                                                15113      0.492500
# 那英                                                 21018      0.431000
# 鄭怡                                                 21339      0.511000
# 金智娟                                                18236      0.511000
# 鈴木 弘                                               9347       0.529000
# 陳秀男                                                11880      0.553500
# 陳蘭麗                                                17682      0.609000
# 霜華雪華                                               759        0.359423
# 韋綺珊                                                20254      0.588000
# 高慧君                                                22672      0.520000
# 黃品源                                                21126      0.578000
# 黑豹                                                 24319      0.353000
# 나현희                                                6962       0.494000
# 칼라 Color                                           7964       0.799000
#
#                                                           duration_ms  \
# artists
# "Cats" 1981 Original London Cast                   4086   247992.0000
# "Cats" 1983 Broadway Cast                          2081   288683.1905
# "Fiddler On The Roof” Motion Picture Chorus        5668   328920.0000
# "Fiddler On The Roof” Motion Picture Orchestra     3039   259237.7143
# "Joseph And The Amazing Technicolor Dreamcoat" ... 4128   218785.3000
# "Joseph And The Amazing Technicolor Dreamcoat" ... 2005   203703.0909
# "Mama" Helen Teagarden                             25428  135533.0000
# "Mista Dj Paul                                     19982  123040.0000
# "Test for Victor Young"                            17886  175693.0000
# "Weird Al" Yankovic                                508    219130.8714
# $IMEON                                             16083   65409.0000
# $NOT                                               7359   148719.2000
# $pyda                                              19531  331240.0000
# $uicideBoy$                                        565    148648.4769
# 'Be More Chill' Ensemble                           23275  164400.0000
# 'In The Heights' Original Broadway Company         4453   298694.8889
# 'Legally Blonde' Ensemble                          4452   273237.0000
# 'Legally Blonde' Greek Chorus                      12827  361780.0000
# 'Little Women' Original Broadway Cast              20927  275360.0000
# 'The Book of Mormon' Original Broadway Cast Com... 22893  243893.0000
# 'Til Tuesday                                       4956   255213.5000
# ((( O )))                                          19283  311837.0000
# (Con La Participación De Eros Ramazzotti)          21640  287600.0000
# (G)I-DLE                                           13704  193483.5000
# (Hed) P.E.                                         6367   250835.6667
# (Sandy) Alex G                                     16865  176147.0000
# *NSYNC                                             915    235723.1364
# -                                                  15435  316307.0000
# ...And You Will Know Us by the Trail of Dead       26104  273624.0000
# ...Bender                                          26720  226000.0000
# ...                                                               ...
# 王秀如                                                3515   207722.1667
# 環球管弦樂隊                                             4538   101589.2222
# 白光                                                 1835   172030.5833
# 福居良                                                5972   413395.6667
# 秋元薫                                                9469   286666.6667
# 童安格                                                10168  235373.3333
# 笠井 紀美子                                             15355  428427.0000
# 紫薇                                                 700    199313.7273
# 羅大佑                                                7022   276351.8000
# 葉歡                                                 23903  309333.0000
# 葛蘭                                                 2088   188991.7619
# 蔡楓華                                                23806  185320.0000
# 蔣志光                                                21659  266000.0000
# 虞戡平                                                18384  218973.0000
# 謝雷                                                 22682  197293.0000
# 賴佩霞                                                16732  234386.0000
# 辛曉琪                                                15113  266080.0000
# 那英                                                 21018  232333.0000
# 鄭怡                                                 21339  320720.0000
# 金智娟                                                18236  320720.0000
# 鈴木 弘                                               9347   492800.0000
# 陳秀男                                                11880  263286.5000
# 陳蘭麗                                                17682  152883.0000
# 霜華雪華                                               759    212516.5769
# 韋綺珊                                                20254  266000.0000
# 高慧君                                                22672  286840.0000
# 黃品源                                                21126  293840.0000
# 黑豹                                                 24319  316160.0000
# 나현희                                                6962   215672.2000
# 칼라 Color                                           7964   240400.2500
#
#                                                             energy  \
# artists
# "Cats" 1981 Original London Cast                   4086   0.367503
# "Cats" 1983 Broadway Cast                          2081   0.385714
# "Fiddler On The Roof” Motion Picture Chorus        5668   0.286571
# "Fiddler On The Roof” Motion Picture Orchestra     3039   0.241779
# "Joseph And The Amazing Technicolor Dreamcoat" ... 4128   0.546500
# "Joseph And The Amazing Technicolor Dreamcoat" ... 2005   0.325059
# "Mama" Helen Teagarden                             25428  0.512000
# "Mista Dj Paul                                     19982  0.487000
# "Test for Victor Young"                            17886  0.474000
# "Weird Al" Yankovic                                508    0.690800
# $IMEON                                             16083  0.535000
# $NOT                                               7359   0.520200
# $pyda                                              19531  0.899000
# $uicideBoy$                                        565    0.643015
# 'Be More Chill' Ensemble                           23275  0.474000
# 'In The Heights' Original Broadway Company         4453   0.393378
# 'Legally Blonde' Ensemble                          4452   0.420667
# 'Legally Blonde' Greek Chorus                      12827  0.309500
# 'Little Women' Original Broadway Cast              20927  0.325000
# 'The Book of Mormon' Original Broadway Cast Com... 22893  0.659000
# 'Til Tuesday                                       4956   0.612250
# ((( O )))                                          19283  0.169000
# (Con La Participación De Eros Ramazzotti)          21640  0.628000
# (G)I-DLE                                           13704  0.765500
# (Hed) P.E.                                         6367   0.876500
# (Sandy) Alex G                                     16865  0.686000
# *NSYNC                                             915    0.730864
# -                                                  15435  0.546000
# ...And You Will Know Us by the Trail of Dead       26104  0.858000
# ...Bender                                          26720  0.894000
# ...                                                            ...
# 王秀如                                                3515   0.043975
# 環球管弦樂隊                                             4538   0.562556
# 白光                                                 1835   0.254167
# 福居良                                                5972   0.371000
# 秋元薫                                                9469   0.541000
# 童安格                                                10168  0.256333
# 笠井 紀美子                                             15355  0.761000
# 紫薇                                                 700    0.295218
# 羅大佑                                                7022   0.494000
# 葉歡                                                 23903  0.568000
# 葛蘭                                                 2088   0.325714
# 蔡楓華                                                23806  0.362000
# 蔣志光                                                21659  0.354000
# 虞戡平                                                18384  0.194000
# 謝雷                                                 22682  0.334000
# 賴佩霞                                                16732  0.050100
# 辛曉琪                                                15113  0.243000
# 那英                                                 21018  0.200000
# 鄭怡                                                 21339  0.547000
# 金智娟                                                18236  0.547000
# 鈴木 弘                                               9347   0.353333
# 陳秀男                                                11880  0.609000
# 陳蘭麗                                                17682  0.833000
# 霜華雪華                                               759    0.069556
# 韋綺珊                                                20254  0.354000
# 高慧君                                                22672  0.285000
# 黃品源                                                21126  0.334000
# 黑豹                                                 24319  0.686000
# 나현희                                                6962   0.496400
# 칼라 Color                                           7964   0.524250
#
#                                                           instrumentalness  \
# artists
# "Cats" 1981 Original London Cast                   4086       1.876072e-02
# "Cats" 1983 Broadway Cast                          2081       5.062928e-02
# "Fiddler On The Roof” Motion Picture Chorus        5668       2.459295e-02
# "Fiddler On The Roof” Motion Picture Orchestra     3039       7.098523e-02
# "Joseph And The Amazing Technicolor Dreamcoat" ... 4128       1.689538e-02
# "Joseph And The Amazing Technicolor Dreamcoat" ... 2005       3.845474e-03
# "Mama" Helen Teagarden                             25428      1.860000e-01
# "Mista Dj Paul                                     19982      4.640000e-01
# "Test for Victor Young"                            17886      7.620000e-02
# "Weird Al" Yankovic                                508        4.370000e-05
# $IMEON                                             16083      0.000000e+00
# $NOT                                               7359       1.350000e-05
# $pyda                                              19531      7.930000e-02
# $uicideBoy$                                        565        4.240573e-02
# 'Be More Chill' Ensemble                           23275      2.230000e-04
# 'In The Heights' Original Broadway Company         4453       7.320000e-06
# 'Legally Blonde' Ensemble                          4452       2.580000e-05
# 'Legally Blonde' Greek Chorus                      12827      0.000000e+00
# 'Little Women' Original Broadway Cast              20927      2.140000e-03
# 'The Book of Mormon' Original Broadway Cast Com... 22893      0.000000e+00
# 'Til Tuesday                                       4956       2.330025e-02
# ((( O )))                                          19283      3.270000e-03
# (Con La Participación De Eros Ramazzotti)          21640      0.000000e+00
# (G)I-DLE                                           13704      7.050000e-07
# (Hed) P.E.                                         6367       1.171880e-04
# (Sandy) Alex G                                     16865      1.880000e-04
# *NSYNC                                             915        3.235237e-03
# -                                                  15435      1.540000e-05
# ...And You Will Know Us by the Trail of Dead       26104      3.550000e-04
# ...Bender                                          26720      1.040000e-03
# ...                                                                    ...
# 王秀如                                                3515       1.730000e-05
# 環球管弦樂隊                                             4538       2.332680e-01
# 白光                                                 1835       1.764192e-01
# 福居良                                                5972       3.808683e-01
# 秋元薫                                                9469       8.282033e-02
# 童安格                                                10168      3.380000e-05
# 笠井 紀美子                                             15355      6.180000e-01
# 紫薇                                                 700        1.476597e-03
# 羅大佑                                                7022       5.170000e-05
# 葉歡                                                 23903      2.770000e-06
# 葛蘭                                                 2088       1.370000e-05
# 蔡楓華                                                23806      3.890000e-05
# 蔣志光                                                21659      5.710000e-06
# 虞戡平                                                18384      1.840000e-05
# 謝雷                                                 22682      0.000000e+00
# 賴佩霞                                                16732      3.190000e-03
# 辛曉琪                                                15113      1.870000e-05
# 那英                                                 21018      0.000000e+00
# 鄭怡                                                 21339      1.020000e-06
# 金智娟                                                18236      1.020000e-06
# 鈴木 弘                                               9347       8.260000e-01
# 陳秀男                                                11880      3.918500e-04
# 陳蘭麗                                                17682      0.000000e+00
# 霜華雪華                                               759        4.650894e-03
# 韋綺珊                                                20254      5.710000e-06
# 高慧君                                                22672      0.000000e+00
# 黃品源                                                21126      5.950000e-06
# 黑豹                                                 24319      0.000000e+00
# 나현희                                                6962       1.990079e-01
# 칼라 Color                                           7964       6.180400e-04
#
#                                                           liveness   loudness  \
# artists
# "Cats" 1981 Original London Cast                   4086   0.303250 -14.326800
# "Cats" 1983 Broadway Cast                          2081   0.269790 -10.711762
# "Fiddler On The Roof” Motion Picture Chorus        5668   0.325786 -15.230714
# "Fiddler On The Roof” Motion Picture Orchestra     3039   0.270536 -15.701429
# "Joseph And The Amazing Technicolor Dreamcoat" ... 4128   0.218800 -10.020400
# "Joseph And The Amazing Technicolor Dreamcoat" ... 2005   0.293218 -18.032818
# "Mama" Helen Teagarden                             25428  0.426000 -20.615000
# "Mista Dj Paul                                     19982  0.146000  -9.664000
# "Test for Victor Young"                            17886  0.737000 -10.544000
# "Weird Al" Yankovic                                508    0.164766  -9.891629
# $IMEON                                             16083  0.117000 -10.834000
# $NOT                                               7359   0.191760  -9.084200
# $pyda                                              19531  0.367000  -5.115000
# $uicideBoy$                                        565    0.190865  -6.594585
# 'Be More Chill' Ensemble                           23275  0.453000  -7.279000
# 'In The Heights' Original Broadway Company         4453   0.188944  -9.480778
# 'Legally Blonde' Ensemble                          4452   0.251844 -10.987111
# 'Legally Blonde' Greek Chorus                      12827  0.222200 -12.669000
# 'Little Women' Original Broadway Cast              20927  0.072100  -7.955000
# 'The Book of Mormon' Original Broadway Cast Com... 22893  0.078000  -8.372000
# 'Til Tuesday                                       4956   0.127587  -9.638125
# ((( O )))                                          19283  0.117000 -11.422000
# (Con La Participación De Eros Ramazzotti)          21640  0.125000  -5.713000
# (G)I-DLE                                           13704  0.149500  -3.933500
# (Hed) P.E.                                         6367   0.151250  -5.239500
# (Sandy) Alex G                                     16865  0.138000  -5.198000
# *NSYNC                                             915    0.217316  -5.861386
# -                                                  15435  0.193000  -7.022000
# ...And You Will Know Us by the Trail of Dead       26104  0.513000  -5.085000
# ...Bender                                          26720  0.116000  -5.025000
# ...                                                            ...        ...
# 王秀如                                                3515   0.144533 -25.468250
# 環球管弦樂隊                                             4538   0.141700  -2.807000
# 白光                                                 1835   0.175658 -12.003750
# 福居良                                                5972   0.163417 -12.028500
# 秋元薫                                                9469   0.234867 -14.102667
# 童安格                                                10168  0.133333 -16.209333
# 笠井 紀美子                                             15355  0.063000 -14.346000
# 紫薇                                                 700    0.162178 -12.808964
# 羅大佑                                                7022   0.207400  -9.377000
# 葉歡                                                 23903  0.048300 -10.024000
# 葛蘭                                                 2088   0.187033 -10.309143
# 蔡楓華                                                23806  0.102000 -13.157000
# 蔣志光                                                21659  0.144000 -14.259000
# 虞戡平                                                18384  0.153000 -12.811000
# 謝雷                                                 22682  0.086100 -14.152000
# 賴佩霞                                                16732  0.087300 -26.692000
# 辛曉琪                                                15113  0.133500 -14.258500
# 那英                                                 21018  0.257000 -10.870000
# 鄭怡                                                 21339  0.584000 -10.864000
# 金智娟                                                18236  0.584000 -10.864000
# 鈴木 弘                                               9347   0.088600 -14.204333
# 陳秀男                                                11880  0.229000  -9.361000
# 陳蘭麗                                                17682  0.134000  -6.261000
# 霜華雪華                                               759    0.142665 -23.470788
# 韋綺珊                                                20254  0.144000 -14.259000
# 高慧君                                                22672  0.093100 -10.754000
# 黃品源                                                21126  0.067500 -11.974000
# 黑豹                                                 24319  0.056800  -9.103000
# 나현희                                                6962   0.276760 -12.787400
# 칼라 Color                                           7964   0.229975 -11.734250
#
#                                                           speechiness  \
# artists
# "Cats" 1981 Original London Cast                   4086      0.175180
# "Cats" 1983 Broadway Cast                          2081      0.139271
# "Fiddler On The Roof” Motion Picture Chorus        5668      0.118514
# "Fiddler On The Roof” Motion Picture Orchestra     3039      0.120171
# "Joseph And The Amazing Technicolor Dreamcoat" ... 4128      0.108330
# "Joseph And The Amazing Technicolor Dreamcoat" ... 2005      0.100300
# "Mama" Helen Teagarden                             25428     0.210000
# "Mista Dj Paul                                     19982     0.351000
# "Test for Victor Young"                            17886     0.256000
# "Weird Al" Yankovic                                508       0.082156
# $IMEON                                             16083     0.147000
# $NOT                                               7359      0.299880
# $pyda                                              19531     0.060200
# $uicideBoy$                                        565       0.157475
# 'Be More Chill' Ensemble                           23275     0.044000
# 'In The Heights' Original Broadway Company         4453      0.145356
# 'Legally Blonde' Ensemble                          4452      0.473000
# 'Legally Blonde' Greek Chorus                      12827     0.289000
# 'Little Women' Original Broadway Cast              20927     0.035400
# 'The Book of Mormon' Original Broadway Cast Com... 22893     0.263000
# 'Til Tuesday                                       4956      0.032150
# ((( O )))                                          19283     0.048500
# (Con La Participación De Eros Ramazzotti)          21640     0.052200
# (G)I-DLE                                           13704     0.063200
# (Hed) P.E.                                         6367      0.156450
# (Sandy) Alex G                                     16865     0.031400
# *NSYNC                                             915       0.067568
# -                                                  15435     0.045000
# ...And You Will Know Us by the Trail of Dead       26104     0.069400
# ...Bender                                          26720     0.053700
# ...                                                               ...
# 王秀如                                                3515      0.038383
# 環球管弦樂隊                                             4538      0.048144
# 白光                                                 1835      0.046867
# 福居良                                                5972      0.037417
# 秋元薫                                                9469      0.043567
# 童安格                                                10168     0.032300
# 笠井 紀美子                                             15355     0.047600
# 紫薇                                                 700       0.038785
# 羅大佑                                                7022      0.034200
# 葉歡                                                 23903     0.027800
# 葛蘭                                                 2088      0.060419
# 蔡楓華                                                23806     0.025600
# 蔣志光                                                21659     0.027000
# 虞戡平                                                18384     0.027800
# 謝雷                                                 22682     0.039300
# 賴佩霞                                                16732     0.040700
# 辛曉琪                                                15113     0.039400
# 那英                                                 21018     0.044900
# 鄭怡                                                 21339     0.046900
# 金智娟                                                18236     0.046900
# 鈴木 弘                                               9347      0.040233
# 陳秀男                                                11880     0.035300
# 陳蘭麗                                                17682     0.215000
# 霜華雪華                                               759       0.050446
# 韋綺珊                                                20254     0.027000
# 高慧君                                                22672     0.027000
# 黃品源                                                21126     0.026700
# 黑豹                                                 24319     0.039500
# 나현희                                                6962      0.039800
# 칼라 Color                                           7964      0.034025
#
#                                                            valence  popularity
# artists
# "Cats" 1981 Original London Cast                   4086   0.358320   38.400000
# "Cats" 1983 Broadway Cast                          2081   0.282690   33.380952
# "Fiddler On The Roof” Motion Picture Chorus        5668   0.354857   35.000000
# "Fiddler On The Roof” Motion Picture Orchestra     3039   0.362529   35.214286
# "Joseph And The Amazing Technicolor Dreamcoat" ... 4128   0.455600   40.800000
# "Joseph And The Amazing Technicolor Dreamcoat" ... 2005   0.449573   34.863636
# "Mama" Helen Teagarden                             25428  0.885000    0.000000
# "Mista Dj Paul                                     19982  0.499000   37.000000
# "Test for Victor Young"                            17886  0.902000    2.000000
# "Weird Al" Yankovic                                508    0.762214   33.814286
# $IMEON                                             16083  0.244000   64.000000
# $NOT                                               7359   0.316900   64.000000
# $pyda                                              19531  0.266000   58.000000
# $uicideBoy$                                        565    0.289583   61.353846
# 'Be More Chill' Ensemble                           23275  0.493000   52.000000
# 'In The Heights' Original Broadway Company         4453   0.393111   47.777778
# 'Legally Blonde' Ensemble                          4452   0.543222   48.333333
# 'Legally Blonde' Greek Chorus                      12827  0.596500   49.500000
# 'Little Women' Original Broadway Cast              20927  0.168000   42.000000
# 'The Book of Mormon' Original Broadway Cast Com... 22893  0.457000   47.000000
# 'Til Tuesday                                       4956   0.532625   35.000000
# ((( O )))                                          19283  0.208000   66.000000
# (Con La Participación De Eros Ramazzotti)          21640  0.561000   43.000000
# (G)I-DLE                                           13704  0.433500   75.500000
# (Hed) P.E.                                         6367   0.426000   42.666667
# (Sandy) Alex G                                     16865  0.497000   51.000000
# *NSYNC                                             915    0.625773   45.295455
# -                                                  15435  0.376000   55.000000
# ...And You Will Know Us by the Trail of Dead       26104  0.237000   35.000000
# ...Bender                                          26720  0.336000   41.000000
# ...                                                            ...         ...
# 王秀如                                                3515   0.297250   24.000000
# 環球管弦樂隊                                             4538   0.527333   25.333333
# 白光                                                 1835   0.433042    2.375000
# 福居良                                                5972   0.265217   39.000000
# 秋元薫                                                9469   0.716333   35.000000
# 童安格                                                10168  0.196933   40.333333
# 笠井 紀美子                                             15355  0.881000   39.000000
# 紫薇                                                 700    0.425473    6.527273
# 羅大佑                                                7022   0.547000   33.400000
# 葉歡                                                 23903  0.174000   38.000000
# 葛蘭                                                 2088   0.560667    2.666667
# 蔡楓華                                                23806  0.321000   33.000000
# 蔣志光                                                21659  0.398000   40.000000
# 虞戡平                                                18384  0.262000   39.000000
# 謝雷                                                 22682  0.523000   23.000000
# 賴佩霞                                                16732  0.071400   23.000000
# 辛曉琪                                                15113  0.133700   46.500000
# 那英                                                 21018  0.309000   47.000000
# 鄭怡                                                 21339  0.372000   47.000000
# 金智娟                                                18236  0.372000   47.000000
# 鈴木 弘                                               9347   0.453667   32.333333
# 陳秀男                                                11880  0.535500   43.500000
# 陳蘭麗                                                17682  0.718000   34.000000
# 霜華雪華                                               759    0.337492   22.288462
# 韋綺珊                                                20254  0.398000   40.000000
# 高慧君                                                22672  0.079800   51.000000
# 黃品源                                                21126  0.243000   47.000000
# 黑豹                                                 24319  0.352000   34.000000
# 나현희                                                6962   0.340460    0.000000
# 칼라 Color                                           7964   0.782000    0.000000
#
# [27606 rows x 11 columns]
