# %% [markdown]
# # Analysis of the sonic effects of music
# ##### Author: Otuokere Tobechukwu. O
# ##### Github: github.com/OtuokereTobechukwu

# %% [markdown]
# ### Introduction
#
# Music has been a wonder since time began.
# Don't try imagining Life without it.
#
# Frequently, very interesting questions pop up in my mind as regards how we humans percieve the sonic contents of music and how it affects us.
#
# This is an attempt, through Exploratory Data Analysis, to explain how different elements of music correlate with each other.

# %% [markdown]
# ## Importing essential libraries and dataset

# %%
# Importing needed libraries
import time
import warnings
import pandas  as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Importing the dataset

# %%
dataset = pd.read_csv('data.csv')

# Overview of the dataset.
dataset.head()
# Out:
#    Unnamed: 0  acousticness  \
# 0           0         0.732
# 1           1         0.982
# 2           2         0.996
# 3           3         0.982
# 4           4         0.957
#
#                                              artists  danceability  \
# 0                                     ['Dennis Day']         0.819
# 1  ['Sergei Rachmaninoff', 'James Levine', 'Berli...         0.279
# 2                                 ['John McCormack']         0.518
# 3  ['Sergei Rachmaninoff', 'James Levine', 'Berli...         0.279
# 4                                     ['Phil Regan']         0.418
#
#    duration_ms  energy  explicit                      id  instrumentalness  \
# 0       180533   0.341         0  7xPhfUan2yNtyFG0cUWkt8          0.000000
# 1       831667   0.211         0  4BJqT0PrAfrxzMOxytFOIz          0.878000
# 2       159507   0.203         0  5uNZnElqOS3W4fRmRYPk4T          0.000000
# 3       831667   0.211         0  1SCWBjhk5WmXPxhDduD3HM          0.878000
# 4       166693   0.193         0  4d6HGyGT8e121BsdKmw9v6          0.000002
#
#    key  liveness  loudness  mode  \
# 0    7     0.160   -12.441     1
# 1   10     0.665   -20.096     1
# 2    0     0.115   -10.589     1
# 3   10     0.665   -20.096     1
# 4    3     0.229   -10.096     1
#
#                                                 name  popularity release_date  \
# 0                            Clancy Lowered the Boom           8         1921
# 1  Piano Concerto No. 3 in D Minor, Op. 30: III. ...           5         1921
# 2                           The Wearing of the Green           6         1921
# 3  Piano Concerto No. 3 in D Minor, Op. 30: III. ...           4         1921
# 4                        When Irish Eyes Are Smiling           4         1921
#
#    speechiness    tempo  valence  year
# 0       0.4150   60.936   0.9630  1921
# 1       0.0366   80.954   0.0594  1921
# 2       0.0615   66.221   0.4060  1921
# 3       0.0366   80.954   0.0594  1921
# 4       0.0380  101.665   0.2530  1921

# %% [markdown]
# ### Descriptive Statistics

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168592 entries, 0 to 168591
# Data columns (total 19 columns):
# acousticness        168592 non-null float64
# artists             168592 non-null object
# danceability        168592 non-null float64
# duration_ms         168592 non-null int64
# energy              168592 non-null float64
# explicit            168592 non-null int64
# id                  168592 non-null object
# instrumentalness    168592 non-null float64
# key                 168592 non-null int64
# liveness            168592 non-null float64
# loudness            168592 non-null float64
# mode                168592 non-null int64
# name                168592 non-null object
# popularity          168592 non-null int64
# release_date        168592 non-null object
# speechiness         168592 non-null float64
# tempo               168592 non-null float64
# valence             168592 non-null float64
# year                168592 non-null int64
# dtypes: float64(9), int64(6), object(4)
# memory usage: 24.4+ MB

# %%
# Descriptive statistics of the dataset
dataset.describe()
# Out:
#           Unnamed: 0   acousticness   danceability   duration_ms  \
# count  168592.000000  168592.000000  168592.000000  1.685920e+05
# mean    84295.500000       0.501360       0.533648  2.327016e+05
# std     48668.462629       0.377993       0.175919  1.223921e+05
# min         0.000000       0.000000       0.000000  5.108000e+03
# 25%     42147.750000       0.097800       0.412000  1.721600e+05
# 50%     84295.500000       0.515000       0.543000  2.091330e+05
# 75%    126443.250000       0.896000       0.662000  2.637070e+05
# max    168591.000000       0.996000       0.988000  5.403500e+06
#
#               energy       explicit  instrumentalness            key  \
# count  168592.000000  168592.000000     168592.000000  168592.000000
# mean        0.488577       0.071516          0.169476       5.196795
# std         0.267346       0.257685          0.315383       3.504587
# min         0.000000       0.000000          0.000000       0.000000
# 25%         0.265000       0.000000          0.000000       2.000000
# 50%         0.480000       0.000000          0.000264       5.000000
# 75%         0.709000       0.000000          0.111000       8.000000
# max         1.000000       1.000000          1.000000      11.000000
#
#             liveness       loudness           mode     popularity  \
# count  168592.000000  168592.000000  168592.000000  168592.000000
# mean        0.205151     -11.358180       0.709446      31.626862
# std         0.175896       5.670176       0.454019      21.393260
# min         0.000000     -60.000000       0.000000       0.000000
# 25%         0.098200     -14.388000       0.000000      13.000000
# 50%         0.134000     -10.466000       1.000000      34.000000
# 75%         0.259000      -7.135000       1.000000      48.000000
# max         1.000000       3.855000       1.000000     100.000000
#
#          speechiness          tempo        valence           year
# count  168592.000000  168592.000000  168592.000000  168592.000000
# mean        0.083616     116.918295       0.528497    1977.457774
# std         0.119917      30.726527       0.264457      25.406757
# min         0.000000       0.000000       0.000000    1921.000000
# 25%         0.034800      93.500750       0.315000    1957.000000
# 50%         0.044600     114.795000       0.539000    1978.000000
# 75%         0.072300     135.733500       0.749000    1999.000000
# max         0.968000     244.091000       1.000000    2020.000000

# %% [markdown]
# #### A few points to note from the descriptive statistics above
#
# The acousticness, danceability, energy, explicit, instrumentalness, liveness, mode, speechiness and valence columnns all have a minimum value of 0 and a maximum value of 1 except for a few instances which can be rounded off as 1. This implies that all values in the columns above all fall within the Bad(0) and GOOD(1) range.
#
# Another interesting feature would be the "loudness" column.
# Sound levels are measured in DECIBELS(db).
# The closer you are to 0db, the louder it becomes. Frequencies above 0db are usually distorted and as a result, the industry standard as regards loudness is maxed at 0db.
# This explains why we have negative values with a minimum and maximum value of -60db and 3.86db respectively.
#
#
# Moving on.......

# %% [markdown]
# ### A little data processing ...
#
# The first column in the dataframe is not essential for this analysis.
#
# Also, we won't be needing the categorical columns just yet so we are going to drop them.

# %%
# Dropping the First column

dataset = dataset.drop(columns = dataset.columns[0])

# %%
# Dropping all categorical variables

cat_cols = ['artists', 'name', 'id']
numeric_cols = dataset.drop(columns=cat_cols)
numeric_cols.head()
# Out:
#    acousticness  danceability  duration_ms  energy  explicit  \
# 0         0.732         0.819       180533   0.341         0
# 1         0.982         0.279       831667   0.211         0
# 2         0.996         0.518       159507   0.203         0
# 3         0.982         0.279       831667   0.211         0
# 4         0.957         0.418       166693   0.193         0
#
#    instrumentalness  key  liveness  loudness  mode  popularity release_date  \
# 0          0.000000    7     0.160   -12.441     1           8         1921
# 1          0.878000   10     0.665   -20.096     1           5         1921
# 2          0.000000    0     0.115   -10.589     1           6         1921
# 3          0.878000   10     0.665   -20.096     1           4         1921
# 4          0.000002    3     0.229   -10.096     1           4         1921
#
#    speechiness    tempo  valence  year
# 0       0.4150   60.936   0.9630  1921
# 1       0.0366   80.954   0.0594  1921
# 2       0.0615   66.221   0.4060  1921
# 3       0.0366   80.954   0.0594  1921
# 4       0.0380  101.665   0.2530  1921

# %% [markdown]
# In terms of the duration of songs, the millisecond is the unit of measurement in this dataset
#
# We'll need to convert that to minutes to get a more representative idea

# %%
numeric_cols['duration_mins'] = (numeric_cols['duration_ms']/(1000*60))%60
numeric_cols = numeric_cols.drop(columns = ['duration_ms'])
numeric_cols.head()
# Out:
#    acousticness  danceability  energy  explicit  instrumentalness  key  \
# 0         0.732         0.819   0.341         0          0.000000    7
# 1         0.982         0.279   0.211         0          0.878000   10
# 2         0.996         0.518   0.203         0          0.000000    0
# 3         0.982         0.279   0.211         0          0.878000   10
# 4         0.957         0.418   0.193         0          0.000002    3
#
#    liveness  loudness  mode  popularity release_date  speechiness    tempo  \
# 0     0.160   -12.441     1           8         1921       0.4150   60.936
# 1     0.665   -20.096     1           5         1921       0.0366   80.954
# 2     0.115   -10.589     1           6         1921       0.0615   66.221
# 3     0.665   -20.096     1           4         1921       0.0366   80.954
# 4     0.229   -10.096     1           4         1921       0.0380  101.665
#
#    valence  year  duration_mins
# 0   0.9630  1921       3.008883
# 1   0.0594  1921      13.861117
# 2   0.4060  1921       2.658450
# 3   0.0594  1921      13.861117
# 4   0.2530  1921       2.778217

# %% [markdown]
# Now that has been dropped. Let's get visual!
#
# Let's begin by showcasing the distrubution of the sonic features in this dataset

# %% [markdown]
# ### Distrubution of the sonic features

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
numeric_cols.hist(bins=50, figsize=(20,15))
plt.show()

# %% [markdown]
# The above visual showcases the distrubution of the sonic features in this dataset.
#
# Let's briefly highlight some of the striking patterns we can observe here:
#
# #### Danceability
# This feature is normally distrubuted with the values centered around the mean(0.53). A little outlier exists on the left of the distrubution curve which indicates that a few songs were not danceable at all. I wonder what that sounds like.
#
# #### Duration(minutes)
# A lot of songs appear to be within 2-6 minutes mark with a few exceptions lasting up to about 12-15 mins. Pretty long isn't it?
#
# #### Energy
# Energy seems to be fairly uniformly distrubuted
#
# #### Loudness
#
# #### Tempo
# Measured in Beats Per Minute(bpm).
# This feature apppears to be fairly normally distrubuted with most songs falling between 70bpm - 150bpm

# %% [markdown]
# #### Next, we take a look at the correlation between features in this dataset.

# %%
# A seaborn Correlation matrix
sns.set(style = "white", font_scale = 1)

corr = numeric_cols.corr()

mask = np.zeros_like(corr, dtype = np.bool)
mask[np.triu_indices_from(mask)] = True

f, ax = plt.subplots(figsize = (20, 15))
f.suptitle('Correlation Matrix of sonic Characteristics', fontsize = 20)

cmap = sns.diverging_palette(520, 10, as_cmap= True)

sns.heatmap(corr, mask=mask, cmap=cmap, vmax= 3, center = 0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

plt.show()
